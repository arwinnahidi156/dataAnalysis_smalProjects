# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
const=pd.read_html("https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average")[1]

# %%
const=const.iloc[:,:5].copy()

# %%
const.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Company     30 non-null     object
#  1   Exchange    30 non-null     object
#  2   Symbol      30 non-null     object
#  3   Industry    30 non-null     object
#  4   Date added  30 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB

# %%
const.rename(columns={'Date added':'Date_added'},inplace=True)

# %%
const
# Out:
#                      Company Exchange Symbol                        Industry  \
# 0                         3M     NYSE    MMM                    Conglomerate
# 1           American Express     NYSE    AXP              Financial services
# 2                      Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3                      Apple   NASDAQ   AAPL          Information technology
# 4                     Boeing     NYSE     BA           Aerospace and defense
# 5                Caterpillar     NYSE    CAT         Construction and mining
# 6                    Chevron     NYSE    CVX              Petroleum industry
# 7                      Cisco   NASDAQ   CSCO          Information technology
# 8                  Coca-Cola     NYSE     KO                  Drink industry
# 9                     Disney     NYSE    DIS  Broadcasting and entertainment
# 10                       Dow     NYSE    DOW               Chemical industry
# ...

# %%
const.Date_added=pd.to_datetime(const.Date_added)

# %%
const.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Company     30 non-null     object
#  1   Exchange    30 non-null     object
#  2   Symbol      30 non-null     object
#  3   Industry    30 non-null     object
#  4   Date_added  30 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 1.3+ KB

# %%
const.Symbol[0]
# Out:
# 'MMM'

# %%
ticker_list=const.Symbol.to_list()

# %%
pd.read_csv('const.csv')
# Out:
#                      Company Exchange     Symbol  \
# 0                         3M     NYSE  NYSE: MMM
# 1           American Express     NYSE  NYSE: AXP
# 2                 Apple Inc.   NASDAQ       AAPL
# 3                     Boeing     NYSE   NYSE: BA
# 4           Caterpillar Inc.     NYSE  NYSE: CAT
# 5        Chevron Corporation     NYSE  NYSE: CVX
# 6              Cisco Systems   NASDAQ       CSCO
# 7      The Coca-Cola Company     NYSE   NYSE: KO
# 8                   Dow Inc.     NYSE  NYSE: DOW
# 9                 ExxonMobil     NYSE  NYSE: XOM
# 10             Goldman Sachs     NYSE   NYSE: GS
# 11            The Home Depot     NYSE   NYSE: HD
# 12                       IBM     NYSE  NYSE: IBM
# 13                     Intel   NASDAQ       INTC
# 14         Johnson & Johnson     NYSE  NYSE: JNJ
# 15            JPMorgan Chase     NYSE  NYSE: JPM
# 16                McDonald's     NYSE  NYSE: MCD
# 17               Merck & Co.     NYSE  NYSE: MRK
# ...

# %%
dji=yf.download('DJI',start="2007-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dji
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-01-03  12474.500000  12474.500000  12474.500000  12474.500000
# 2007-01-04  12480.700195  12480.700195  12480.700195  12480.700195
# 2007-01-05  12398.000000  12398.000000  12398.000000  12398.000000
# 2007-01-08  12423.500000  12423.500000  12423.500000  12423.500000
# 2007-01-09  12416.599609  12416.599609  12416.599609  12416.599609
# ...                  ...           ...           ...           ...
# 2022-02-24  33223.800781  33223.800781  33223.800781  33223.800781
# 2022-02-25  34058.800781  34058.800781  34058.800781  34058.800781
# 2022-02-28  33892.601562  33892.601562  33892.601562  33892.601562
# 2022-03-01  33294.898438  33294.898438  33294.898438  33294.898438
# 2022-03-02  33891.300781  33891.300781  33891.300781  33891.300781
#
#                Adj Close  Volume
# Date
# 2007-01-03  12474.500000       0
# 2007-01-04  12480.700195       0
# 2007-01-05  12398.000000       0
# ...

# %%
dji.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3646 entries, 2007-01-03 to 2022-03-02
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3646 non-null   float64
#  1   High       3646 non-null   float64
#  2   Low        3646 non-null   float64
#  3   Close      3646 non-null   float64
#  4   Adj Close  3646 non-null   float64
#  5   Volume     3646 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 199.4 KB

# %%
dji.Volume.value_counts()
# Out:
# Volume
# 0            2400
# 197177639       1
# 245131020       1
# 268905853       1
# 227052818       1
#              ...
# 125700522       1
# 84707654        1
# 81503959        1
# 93744501        1
# 357899700       1
# Name: count, Length: 1247, dtype: int64

# %%
ticker_list
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'CRM',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT']

# %%
prices=yf.download(ticker_list,start="2007-01-01",end='2022-03-02')
# Out:
# [*********************100%***********************]  30 of 30 completed

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3817 entries, 2007-01-03 to 2022-03-01
# Columns: 180 entries, ('Adj Close', 'AAPL') to ('Volume', 'WMT')
# dtypes: float64(152), int64(28)
# memory usage: 5.3 MB

# %%
prices
# Out:
#              Adj Close                                                  \
#                   AAPL        AMGN         AXP          BA         CAT
# Date
# 2007-01-03    2.543757   50.349682   46.491989   64.405739   39.171734
# 2007-01-04    2.600218   52.506470   46.153091   64.665741   39.069252
# 2007-01-05    2.581702   52.631618   45.544601   64.391266   38.569683
# 2007-01-08    2.594451   52.212044   45.975933   64.239609   38.614517
# 2007-01-09    2.809971   52.462311   45.683239   63.560654   38.825890
# ...                ...         ...         ...         ...         ...
# 2022-02-23  158.886429  212.179428  185.030594  196.419998  181.413177
# 2022-02-24  161.536682  210.518478  184.443054  198.429993  179.488953
# 2022-02-25  163.631073  217.968735  189.691864  201.479996  181.792191
# 2022-02-28  163.899063  217.440689  190.504623  205.339996  182.297562
# 2022-03-01  161.993286  216.221405  174.366501  194.910004  177.681305
#
# ...

# %%
prices.columns[:100]
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close', 'AMGN'),
#             ('Adj Close',  'AXP'),
#             ('Adj Close',   'BA'),
#             ('Adj Close',  'CAT'),
#             ('Adj Close',  'CRM'),
#             ('Adj Close', 'CSCO'),
#             ('Adj Close',  'CVX'),
#             ('Adj Close',  'DIS'),
#             ('Adj Close',  'DOW'),
#             ('Adj Close',   'GS'),
#             ('Adj Close',   'HD'),
#             ('Adj Close',  'HON'),
#             ('Adj Close',  'IBM'),
#             ('Adj Close', 'INTC'),
#             ('Adj Close',  'JNJ'),
#             ('Adj Close',  'JPM'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'MCD'),
#             ('Adj Close',  'MMM'),
#             ('Adj Close',  'MRK'),
#             ('Adj Close', 'MSFT'),
#             ('Adj Close',  'NKE'),
#             ('Adj Close',   'PG'),
#             ('Adj Close',  'TRV'),
#             ('Adj Close',  'UNH'),
#             ('Adj Close',    'V'),
# ...

# %%
prices=prices.loc[:,'Close'].copy()

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3817 entries, 2007-01-03 to 2022-03-01
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3817 non-null   float64
#  1   AMGN    3817 non-null   float64
#  2   AXP     3817 non-null   float64
#  3   BA      3817 non-null   float64
#  4   CAT     3817 non-null   float64
#  5   CRM     3817 non-null   float64
#  6   CSCO    3817 non-null   float64
#  7   CVX     3817 non-null   float64
#  8   DIS     3817 non-null   float64
#  9   DOW     744 non-null    float64
#  10  GS      3817 non-null   float64
#  11  HD      3817 non-null   float64
#  12  HON     3817 non-null   float64
#  13  IBM     3817 non-null   float64
#  14  INTC    3817 non-null   float64
#  15  JNJ     3817 non-null   float64
#  16  JPM     3817 non-null   float64
#  17  KO      3817 non-null   float64
#  18  MCD     3817 non-null   float64
#  19  MMM     3817 non-null   float64
# ...

# %%
dji.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3646 entries, 2007-01-03 to 2022-03-02
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3646 non-null   float64
#  1   High       3646 non-null   float64
#  2   Low        3646 non-null   float64
#  3   Close      3646 non-null   float64
#  4   Adj Close  3646 non-null   float64
#  5   Volume     3646 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 199.4 KB

# %%
df=dji.loc["2010-01-01":"2020-03-31",'Close'].to_frame()

# %%
df
# Out:
#                    Close
# Date
# 2010-01-04  10584.000000
# 2010-01-05  10572.000000
# 2010-01-06  10573.700195
# 2010-01-07  10606.900391
# 2010-01-08  10618.200195
# ...                  ...
# 2020-03-25  21200.599609
# 2020-03-26  22552.199219
# 2020-03-27  21636.800781
# 2020-03-30  22327.500000
# 2020-03-31  21917.199219
#
# [2429 rows x 1 columns]

# %%
plt.style.use('seaborn')
# Out:
# /tmp/ipykernel_3961/240305066.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
df.describe()
# Out:
#               Close
# count   2429.000000
# mean   17258.461122
# std     4918.351957
# min     9686.480469
# 25%    12921.400391
# 50%    16836.099609
# 75%    20668.000000
# max    29551.400391

# %%
df['Return']=df.pct_change()

# %%
df
# Out:
#                    Close    Return
# Date
# 2010-01-04  10584.000000       NaN
# 2010-01-05  10572.000000 -0.001134
# 2010-01-06  10573.700195  0.000161
# 2010-01-07  10606.900391  0.003140
# 2010-01-08  10618.200195  0.001065
# ...                  ...       ...
# 2020-03-25  21200.599609  0.023941
# 2020-03-26  22552.199219  0.063753
# 2020-03-27  21636.800781 -0.040590
# 2020-03-30  22327.500000  0.031922
# 2020-03-31  21917.199219 -0.018376
#
# [2429 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %%
df.plot(secondary_y='Return',mark_right=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.rename(columns={'Close':'DJI_Close','Return':'DJI_Return'},inplace=True)

# %%
df
# Out:
#                DJI_Close  DJI_Return
# Date
# 2010-01-05  10572.000000   -0.001134
# 2010-01-06  10573.700195    0.000161
# 2010-01-07  10606.900391    0.003140
# 2010-01-08  10618.200195    0.001065
# 2010-01-11  10664.000000    0.004313
# ...                  ...         ...
# 2020-03-25  21200.599609    0.023941
# 2020-03-26  22552.199219    0.063753
# 2020-03-27  21636.800781   -0.040590
# 2020-03-30  22327.500000    0.031922
# 2020-03-31  21917.199219   -0.018376
#
# [2428 rows x 2 columns]

# %%
df['Position']=np.sign(df.DJI_Return)

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position
# Date
# 2010-01-05  10572.000000   -0.001134      -1.0
# 2010-01-06  10573.700195    0.000161       1.0
# 2010-01-07  10606.900391    0.003140       1.0
# 2010-01-08  10618.200195    0.001065       1.0
# 2010-01-11  10664.000000    0.004313       1.0
# ...                  ...         ...       ...
# 2020-03-25  21200.599609    0.023941       1.0
# 2020-03-26  22552.199219    0.063753       1.0
# 2020-03-27  21636.800781   -0.040590      -1.0
# 2020-03-30  22327.500000    0.031922       1.0
# 2020-03-31  21917.199219   -0.018376      -1.0
#
# [2428 rows x 3 columns]

# %%
df['Strategy_ret']=df.Position.shift()*df.DJI_Return

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_ret
# Date
# 2010-01-05  10572.000000   -0.001134      -1.0           NaN
# 2010-01-06  10573.700195    0.000161       1.0     -0.000161
# 2010-01-07  10606.900391    0.003140       1.0      0.003140
# 2010-01-08  10618.200195    0.001065       1.0      0.001065
# 2010-01-11  10664.000000    0.004313       1.0      0.004313
# ...                  ...         ...       ...           ...
# 2020-03-25  21200.599609    0.023941       1.0      0.023941
# 2020-03-26  22552.199219    0.063753       1.0      0.063753
# 2020-03-27  21636.800781   -0.040590      -1.0     -0.040590
# 2020-03-30  22327.500000    0.031922       1.0     -0.031922
# 2020-03-31  21917.199219   -0.018376      -1.0     -0.018376
#
# [2428 rows x 4 columns]

# %%
df['Strategy']=df.Strategy_ret.add(1,fill_value=0).cumprod()*df.iloc[0,0]

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_ret      Strategy
# Date
# 2010-01-05  10572.000000   -0.001134      -1.0           NaN  10572.000000
# 2010-01-06  10573.700195    0.000161       1.0     -0.000161  10570.299805
# 2010-01-07  10606.900391    0.003140       1.0      0.003140  10603.489323
# 2010-01-08  10618.200195    0.001065       1.0      0.001065  10614.785494
# 2010-01-11  10664.000000    0.004313       1.0      0.004313  10660.570570
# ...                  ...         ...       ...           ...           ...
# 2020-03-25  21200.599609    0.023941       1.0      0.023941   5368.309581
# 2020-03-26  22552.199219    0.063753       1.0      0.063753   5710.554860
# 2020-03-27  21636.800781   -0.040590      -1.0     -0.040590   5478.762256
# 2020-03-30  22327.500000    0.031922       1.0     -0.031922   5303.866861
# 2020-03-31  21917.199219   -0.018376      -1.0     -0.018376   5206.400476
#
# [2428 rows x 5 columns]

# %%
df[['DJI_Close','Strategy']].plot()
plt.title("simple momentum strategy")
# Out:
# Text(0.5, 1.0, 'simple momentum strategy')

# %%
summary=df.Strategy_ret.agg(['mean','std']).T
summary['Return']=summary['mean']*252
summary["Risk"]=summary['std']*np.sqrt(252)

# %%
def summary_ann(returns):
    summary=returns.agg(['mean','std']).T
    summary['Return']=summary['mean']*252
    summary['Risk']=summary['std']*np.sqrt(252)
    summary.drop(columns=['mean','std'],inplace=True)
    return summary

# %%
summary_ann(df[['DJI_Return','Strategy_ret']])
# Out:
#                 Return      Risk
# DJI_Return    0.090707  0.173746
# Strategy_ret -0.058327  0.173719

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_ret      Strategy
# Date
# 2010-01-05  10572.000000   -0.001134      -1.0           NaN  10572.000000
# 2010-01-06  10573.700195    0.000161       1.0     -0.000161  10570.299805
# 2010-01-07  10606.900391    0.003140       1.0      0.003140  10603.489323
# 2010-01-08  10618.200195    0.001065       1.0      0.001065  10614.785494
# 2010-01-11  10664.000000    0.004313       1.0      0.004313  10660.570570
# ...                  ...         ...       ...           ...           ...
# 2020-03-25  21200.599609    0.023941       1.0      0.023941   5368.309581
# 2020-03-26  22552.199219    0.063753       1.0      0.063753   5710.554860
# 2020-03-27  21636.800781   -0.040590      -1.0     -0.040590   5478.762256
# 2020-03-30  22327.500000    0.031922       1.0     -0.031922   5303.866861
# 2020-03-31  21917.199219   -0.018376      -1.0     -0.018376   5206.400476
#
# [2428 rows x 5 columns]

# %%
df.drop(columns=['Position','Strategy','Strategy_ret'],inplace=True)

# %%
df
# Out:
#                DJI_Close  DJI_Return
# Date
# 2010-01-05  10572.000000   -0.001134
# 2010-01-06  10573.700195    0.000161
# 2010-01-07  10606.900391    0.003140
# 2010-01-08  10618.200195    0.001065
# 2010-01-11  10664.000000    0.004313
# ...                  ...         ...
# 2020-03-25  21200.599609    0.023941
# 2020-03-26  22552.199219    0.063753
# 2020-03-27  21636.800781   -0.040590
# 2020-03-30  22327.500000    0.031922
# 2020-03-31  21917.199219   -0.018376
#
# [2428 rows x 2 columns]

# %%
df['Position']=-np.sign(df.DJI_Return)

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position
# Date
# 2010-01-05  10572.000000   -0.001134       1.0
# 2010-01-06  10573.700195    0.000161      -1.0
# 2010-01-07  10606.900391    0.003140      -1.0
# 2010-01-08  10618.200195    0.001065      -1.0
# 2010-01-11  10664.000000    0.004313      -1.0
# ...                  ...         ...       ...
# 2020-03-25  21200.599609    0.023941      -1.0
# 2020-03-26  22552.199219    0.063753      -1.0
# 2020-03-27  21636.800781   -0.040590       1.0
# 2020-03-30  22327.500000    0.031922      -1.0
# 2020-03-31  21917.199219   -0.018376       1.0
#
# [2428 rows x 3 columns]

# %%
df['Strategy_ret']=df.Position.shift()*df.DJI_Return

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_ret
# Date
# 2010-01-05  10572.000000   -0.001134       1.0           NaN
# 2010-01-06  10573.700195    0.000161      -1.0      0.000161
# 2010-01-07  10606.900391    0.003140      -1.0     -0.003140
# 2010-01-08  10618.200195    0.001065      -1.0     -0.001065
# 2010-01-11  10664.000000    0.004313      -1.0     -0.004313
# ...                  ...         ...       ...           ...
# 2020-03-25  21200.599609    0.023941      -1.0     -0.023941
# 2020-03-26  22552.199219    0.063753      -1.0     -0.063753
# 2020-03-27  21636.800781   -0.040590       1.0      0.040590
# 2020-03-30  22327.500000    0.031922      -1.0      0.031922
# 2020-03-31  21917.199219   -0.018376       1.0      0.018376
#
# [2428 rows x 4 columns]

# %%
df['Strategy']=df.Strategy_ret.add(1,fill_value=0).cumprod()*df.iloc[0,0]

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_ret      Strategy
# Date
# 2010-01-05  10572.000000   -0.001134       1.0           NaN  10572.000000
# 2010-01-06  10573.700195    0.000161      -1.0      0.000161  10573.700195
# 2010-01-07  10606.900391    0.003140      -1.0     -0.003140  10540.500000
# 2010-01-08  10618.200195    0.001065      -1.0     -0.001065  10529.270933
# 2010-01-11  10664.000000    0.004313      -1.0     -0.004313  10483.854710
# ...                  ...         ...       ...           ...           ...
# 2020-03-25  21200.599609    0.023941      -1.0     -0.023941  15671.527821
# 2020-03-26  22552.199219    0.063753      -1.0     -0.063753  14672.422547
# 2020-03-27  21636.800781   -0.040590       1.0      0.040590  15267.979217
# 2020-03-30  22327.500000    0.031922      -1.0      0.031922  15755.370187
# 2020-03-31  21917.199219   -0.018376       1.0      0.018376  16044.898378
#
# [2428 rows x 5 columns]

# %%
df[['DJI_Close','Strategy']].plot()
plt.title('simple contrarian strategy')
# Out:
# Text(0.5, 1.0, 'simple contrarian strategy')

# %%
summary_ann(df[['DJI_Return','Strategy_ret']])
# Out:
#                 Return      Risk
# DJI_Return    0.090707  0.173746
# Strategy_ret  0.058327  0.173719

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_ret      Strategy
# Date
# 2010-01-05  10572.000000   -0.001134       1.0           NaN  10572.000000
# 2010-01-06  10573.700195    0.000161      -1.0      0.000161  10573.700195
# 2010-01-07  10606.900391    0.003140      -1.0     -0.003140  10540.500000
# 2010-01-08  10618.200195    0.001065      -1.0     -0.001065  10529.270933
# 2010-01-11  10664.000000    0.004313      -1.0     -0.004313  10483.854710
# ...                  ...         ...       ...           ...           ...
# 2020-03-25  21200.599609    0.023941      -1.0     -0.023941  15671.527821
# 2020-03-26  22552.199219    0.063753      -1.0     -0.063753  14672.422547
# 2020-03-27  21636.800781   -0.040590       1.0      0.040590  15267.979217
# 2020-03-30  22327.500000    0.031922      -1.0      0.031922  15755.370187
# 2020-03-31  21917.199219   -0.018376       1.0      0.018376  16044.898378
#
# [2428 rows x 5 columns]

# %%
df.drop(columns=['Position','Strategy_ret','Strategy'],inplace=True)

# %%
df
# Out:
#                DJI_Close  DJI_Return
# Date
# 2010-01-05  10572.000000   -0.001134
# 2010-01-06  10573.700195    0.000161
# 2010-01-07  10606.900391    0.003140
# 2010-01-08  10618.200195    0.001065
# 2010-01-11  10664.000000    0.004313
# ...                  ...         ...
# 2020-03-25  21200.599609    0.023941
# 2020-03-26  22552.199219    0.063753
# 2020-03-27  21636.800781   -0.040590
# 2020-03-30  22327.500000    0.031922
# 2020-03-31  21917.199219   -0.018376
#
# [2428 rows x 2 columns]

# %%
df['Position']=np.where(df.DJI_Return>0.01,-1,1)

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_ret      Strategy
# Date
# 2010-01-05  10572.000000   -0.001134         1           NaN  10572.000000
# 2010-01-06  10573.700195    0.000161         1      0.000161  10573.700195
# 2010-01-07  10606.900391    0.003140         1      0.000000  10573.700195
# 2010-01-08  10618.200195    0.001065         1      0.000000  10573.700195
# 2010-01-11  10664.000000    0.004313         1      0.000000  10573.700195
# ...                  ...         ...       ...           ...           ...
# 2020-03-25  21200.599609    0.023941        -1      0.000000  19179.027485
# 2020-03-26  22552.199219    0.063753        -1      0.000000  19179.027485
# 2020-03-27  21636.800781   -0.040590         1     -0.000000  19179.027485
# 2020-03-30  22327.500000    0.031922        -1      0.031922  19791.268612
# 2020-03-31  21917.199219   -0.018376         1     -0.000000  19791.268612
#
# [2428 rows x 5 columns]

# %%
df['Strategy_ret']=df.Position.shift()*df.DJI_Return
df
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_ret      Strategy
# Date
# 2010-01-05  10572.000000   -0.001134         1           NaN  10572.000000
# 2010-01-06  10573.700195    0.000161         1      0.000161  10573.700195
# 2010-01-07  10606.900391    0.003140         1      0.003140  10573.700195
# 2010-01-08  10618.200195    0.001065         1      0.001065  10573.700195
# 2010-01-11  10664.000000    0.004313         1      0.004313  10573.700195
# ...                  ...         ...       ...           ...           ...
# 2020-03-25  21200.599609    0.023941        -1     -0.023941  19179.027485
# 2020-03-26  22552.199219    0.063753        -1     -0.063753  19179.027485
# 2020-03-27  21636.800781   -0.040590         1      0.040590  19179.027485
# 2020-03-30  22327.500000    0.031922        -1      0.031922  19791.268612
# 2020-03-31  21917.199219   -0.018376         1      0.018376  19791.268612
#
# [2428 rows x 5 columns]

# %%
df['Strategy']=df.Strategy_ret.add(1,fill_value=0).cumprod()*df.iloc[0,0]

# %%
df
# Out:
#                DJI_Close  DJI_Return  Position  Strategy_ret      Strategy
# Date
# 2010-01-05  10572.000000   -0.001134         1           NaN  10572.000000
# 2010-01-06  10573.700195    0.000161         1      0.000161  10573.700195
# 2010-01-07  10606.900391    0.003140         1      0.003140  10606.900391
# 2010-01-08  10618.200195    0.001065         1      0.001065  10618.200195
# 2010-01-11  10664.000000    0.004313         1      0.004313  10664.000000
# ...                  ...         ...       ...           ...           ...
# 2020-03-25  21200.599609    0.023941        -1     -0.023941  40602.792767
# 2020-03-26  22552.199219    0.063753        -1     -0.063753  38014.247167
# 2020-03-27  21636.800781   -0.040590         1      0.040590  39557.253333
# 2020-03-30  22327.500000    0.031922        -1      0.031922  40820.016911
# 2020-03-31  21917.199219   -0.018376         1      0.018376  41570.144997
#
# [2428 rows x 5 columns]

# %%
df[['DJI_Close','Strategy']].plot()
plt.title("simple contrarian strategy")
# Out:
# Text(0.5, 1.0, 'simple contrarian strategy')

# %%
summary_ann(df[['DJI_Return','Strategy_ret']])
# Out:
#                 Return      Risk
# DJI_Return    0.090707  0.173746
# Strategy_ret  0.157216  0.173593

# %%
df.drop(columns=['Position','Strategy_ret','Strategy'],inplace=True)

# %%
df
# Out:
#                DJI_Close  DJI_Return
# Date
# 2010-01-05  10572.000000   -0.001134
# 2010-01-06  10573.700195    0.000161
# 2010-01-07  10606.900391    0.003140
# 2010-01-08  10618.200195    0.001065
# 2010-01-11  10664.000000    0.004313
# ...                  ...         ...
# 2020-03-25  21200.599609    0.023941
# 2020-03-26  22552.199219    0.063753
# 2020-03-27  21636.800781   -0.040590
# 2020-03-30  22327.500000    0.031922
# 2020-03-31  21917.199219   -0.018376
#
# [2428 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                DJI_Close  DJI_Return
# Date
# 2010-01-05  10572.000000   -0.001134
# 2010-01-06  10573.700195    0.000161
# 2010-01-07  10606.900391    0.003140
# 2010-01-08  10618.200195    0.001065
# 2010-01-11  10664.000000    0.004313
# ...                  ...         ...
# 2020-03-25  21200.599609    0.023941
# 2020-03-26  22552.199219    0.063753
# 2020-03-27  21636.800781   -0.040590
# 2020-03-30  22327.500000    0.031922
# 2020-03-31  21917.199219   -0.018376
#
# [2428 rows x 2 columns]

# %%
df.DJI_Close.rolling(window=50).mean()
# Out:
# Date
# 2010-01-05             NaN
# 2010-01-06             NaN
# 2010-01-07             NaN
# 2010-01-08             NaN
# 2010-01-11             NaN
#                   ...
# 2020-03-25    26554.414102
# 2020-03-26    26426.664102
# 2020-03-27    26278.796133
# 2020-03-30    26139.394141
# 2020-03-31    25990.776133
# Name: DJI_Close, Length: 2428, dtype: float64

# %%
df['SMA50']=df.DJI_Close.rolling(window=50).mean()

# %%
df[['DJI_Close','SMA50']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['SMA200']=df.DJI_Close.rolling(window=200).mean()

# %%
df
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200
# Date
# 2010-01-05  10572.000000   -0.001134           NaN           NaN
# 2010-01-06  10573.700195    0.000161           NaN           NaN
# 2010-01-07  10606.900391    0.003140           NaN           NaN
# 2010-01-08  10618.200195    0.001065           NaN           NaN
# 2010-01-11  10664.000000    0.004313           NaN           NaN
# ...                  ...         ...           ...           ...
# 2020-03-25  21200.599609    0.023941  26554.414102  25694.136514
# 2020-03-26  22552.199219    0.063753  26426.664102  25680.543506
# 2020-03-27  21636.800781   -0.040590  26278.796133  25661.419014
# 2020-03-30  22327.500000    0.031922  26139.394141  25644.881514
# 2020-03-31  21917.199219   -0.018376  25990.776133  25623.566006
#
# [2428 rows x 4 columns]

# %%
df[['SMA50','SMA200']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200
# Date
# 2010-10-19  10978.599609   -0.014816  10582.086152  10507.105454
# 2010-10-20  11108.000000    0.011787  10591.362148  10509.785454
# 2010-10-21  11146.599609    0.003475  10606.718145  10512.649951
# 2010-10-22  11132.599609   -0.001256  10622.970137  10515.278447
# 2010-10-25  11164.000000    0.002821  10640.186133  10518.007446
# ...                  ...         ...           ...           ...
# 2020-03-25  21200.599609    0.023941  26554.414102  25694.136514
# 2020-03-26  22552.199219    0.063753  26426.664102  25680.543506
# 2020-03-27  21636.800781   -0.040590  26278.796133  25661.419014
# 2020-03-30  22327.500000    0.031922  26139.394141  25644.881514
# 2020-03-31  21917.199219   -0.018376  25990.776133  25623.566006
#
# [2229 rows x 4 columns]

# %%
df['Position']=np.sign(df.SMA50.sub(df.SMA200))

# %%
df
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position
# Date
# 2010-10-19  10978.599609   -0.014816  10582.086152  10507.105454       1.0
# 2010-10-20  11108.000000    0.011787  10591.362148  10509.785454       1.0
# 2010-10-21  11146.599609    0.003475  10606.718145  10512.649951       1.0
# 2010-10-22  11132.599609   -0.001256  10622.970137  10515.278447       1.0
# 2010-10-25  11164.000000    0.002821  10640.186133  10518.007446       1.0
# ...                  ...         ...           ...           ...       ...
# 2020-03-25  21200.599609    0.023941  26554.414102  25694.136514       1.0
# 2020-03-26  22552.199219    0.063753  26426.664102  25680.543506       1.0
# 2020-03-27  21636.800781   -0.040590  26278.796133  25661.419014       1.0
# 2020-03-30  22327.500000    0.031922  26139.394141  25644.881514       1.0
# 2020-03-31  21917.199219   -0.018376  25990.776133  25623.566006       1.0
#
# [2229 rows x 5 columns]

# %%
df['Strategy_ret']=df.Position.shift()*df.DJI_Return

# %%
df
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position  \
# Date
# 2010-10-19  10978.599609   -0.014816  10582.086152  10507.105454       1.0
# 2010-10-20  11108.000000    0.011787  10591.362148  10509.785454       1.0
# 2010-10-21  11146.599609    0.003475  10606.718145  10512.649951       1.0
# 2010-10-22  11132.599609   -0.001256  10622.970137  10515.278447       1.0
# 2010-10-25  11164.000000    0.002821  10640.186133  10518.007446       1.0
# ...                  ...         ...           ...           ...       ...
# 2020-03-25  21200.599609    0.023941  26554.414102  25694.136514       1.0
# 2020-03-26  22552.199219    0.063753  26426.664102  25680.543506       1.0
# 2020-03-27  21636.800781   -0.040590  26278.796133  25661.419014       1.0
# 2020-03-30  22327.500000    0.031922  26139.394141  25644.881514       1.0
# 2020-03-31  21917.199219   -0.018376  25990.776133  25623.566006       1.0
#
#             Strategy_ret
# Date
# 2010-10-19           NaN
# ...

# %%
df[['SMA50','SMA200','Position']].plot(secondary_y='Position')
# Out:
# <Axes: xlabel='Date'>

# %%
df['Strategy']=df.Strategy_ret.add(1,fill_value=0).cumprod()*df.iloc[0,0]

# %%
df
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position  \
# Date
# 2010-10-19  10978.599609   -0.014816  10582.086152  10507.105454       1.0
# 2010-10-20  11108.000000    0.011787  10591.362148  10509.785454       1.0
# 2010-10-21  11146.599609    0.003475  10606.718145  10512.649951       1.0
# 2010-10-22  11132.599609   -0.001256  10622.970137  10515.278447       1.0
# 2010-10-25  11164.000000    0.002821  10640.186133  10518.007446       1.0
# ...                  ...         ...           ...           ...       ...
# 2020-03-25  21200.599609    0.023941  26554.414102  25694.136514       1.0
# 2020-03-26  22552.199219    0.063753  26426.664102  25680.543506       1.0
# 2020-03-27  21636.800781   -0.040590  26278.796133  25661.419014       1.0
# 2020-03-30  22327.500000    0.031922  26139.394141  25644.881514       1.0
# 2020-03-31  21917.199219   -0.018376  25990.776133  25623.566006       1.0
#
#             Strategy_ret      Strategy
# Date
# ...

# %%
df[['DJI_Close','Strategy']].plot()
plt.title('simpleMA strategy')
# Out:
# Text(0.5, 1.0, 'simpleMA strategy')

# %%
summary_ann(df[['DJI_Return','Strategy_ret']])
# Out:
#                 Return      Risk
# DJI_Return    0.091666  0.173956
# Strategy_ret  0.018437  0.174016

# %%
df['Position']=-np.sign(df.SMA50.sub(df.SMA200))

# %%
df['Strategy_ret']=df.Position.shift()*df.DJI_Return

# %%
df[['SMA50','SMA200','Position']].plot(secondary_y='Position')
# Out:
# <Axes: xlabel='Date'>

# %%
df['Strategy']=df.Strategy_ret.add(1,fill_value=0).cumprod()*df.iloc[0,0]

# %%
df
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position  \
# Date
# 2010-10-19  10978.599609   -0.014816  10582.086152  10507.105454      -1.0
# 2010-10-20  11108.000000    0.011787  10591.362148  10509.785454      -1.0
# 2010-10-21  11146.599609    0.003475  10606.718145  10512.649951      -1.0
# 2010-10-22  11132.599609   -0.001256  10622.970137  10515.278447      -1.0
# 2010-10-25  11164.000000    0.002821  10640.186133  10518.007446      -1.0
# ...                  ...         ...           ...           ...       ...
# 2020-03-25  21200.599609    0.023941  26554.414102  25694.136514      -1.0
# 2020-03-26  22552.199219    0.063753  26426.664102  25680.543506      -1.0
# 2020-03-27  21636.800781   -0.040590  26278.796133  25661.419014      -1.0
# 2020-03-30  22327.500000    0.031922  26139.394141  25644.881514      -1.0
# 2020-03-31  21917.199219   -0.018376  25990.776133  25623.566006      -1.0
#
#             Strategy_ret      Strategy
# Date
# ...

# %%
df[['DJI_Close','Strategy']].plot()
plt.title('simpleMA contrarian strategy')
# Out:
# Text(0.5, 1.0, 'simpleMA contrarian strategy')

# %%
summary_ann(df[['DJI_Return','Strategy_ret']])
# Out:
#                 Return      Risk
# DJI_Return    0.091666  0.173956
# Strategy_ret -0.018437  0.174016

# %%
df['Position']=np.sign(df.DJI_Return)

# %%
df
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position  \
# Date
# 2010-10-19  10978.599609   -0.014816  10582.086152  10507.105454      -1.0
# 2010-10-20  11108.000000    0.011787  10591.362148  10509.785454       1.0
# 2010-10-21  11146.599609    0.003475  10606.718145  10512.649951       1.0
# 2010-10-22  11132.599609   -0.001256  10622.970137  10515.278447      -1.0
# 2010-10-25  11164.000000    0.002821  10640.186133  10518.007446       1.0
# ...                  ...         ...           ...           ...       ...
# 2020-03-25  21200.599609    0.023941  26554.414102  25694.136514       1.0
# 2020-03-26  22552.199219    0.063753  26426.664102  25680.543506       1.0
# 2020-03-27  21636.800781   -0.040590  26278.796133  25661.419014      -1.0
# 2020-03-30  22327.500000    0.031922  26139.394141  25644.881514       1.0
# 2020-03-31  21917.199219   -0.018376  25990.776133  25623.566006      -1.0
#
#             Strategy_ret      Strategy
# Date
# ...

# %%
df['Strategy_ret']=df.Position*df.DJI_Return

# %%
df
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position  \
# Date
# 2010-10-19  10978.599609   -0.014816  10582.086152  10507.105454      -1.0
# 2010-10-20  11108.000000    0.011787  10591.362148  10509.785454       1.0
# 2010-10-21  11146.599609    0.003475  10606.718145  10512.649951       1.0
# 2010-10-22  11132.599609   -0.001256  10622.970137  10515.278447      -1.0
# 2010-10-25  11164.000000    0.002821  10640.186133  10518.007446       1.0
# ...                  ...         ...           ...           ...       ...
# 2020-03-25  21200.599609    0.023941  26554.414102  25694.136514       1.0
# 2020-03-26  22552.199219    0.063753  26426.664102  25680.543506       1.0
# 2020-03-27  21636.800781   -0.040590  26278.796133  25661.419014      -1.0
# 2020-03-30  22327.500000    0.031922  26139.394141  25644.881514       1.0
# 2020-03-31  21917.199219   -0.018376  25990.776133  25623.566006      -1.0
#
#             Strategy_ret      Strategy
# Date
# ...

# %%
df['Strategy']=df.Strategy_ret.add(1,fill_value=0).cumprod()*df.iloc[0,0]

# %%
df
# Out:
#                DJI_Close  DJI_Return         SMA50        SMA200  Position  \
# Date
# 2010-10-19  10978.599609   -0.014816  10582.086152  10507.105454      -1.0
# 2010-10-20  11108.000000    0.011787  10591.362148  10509.785454       1.0
# 2010-10-21  11146.599609    0.003475  10606.718145  10512.649951       1.0
# 2010-10-22  11132.599609   -0.001256  10622.970137  10515.278447      -1.0
# 2010-10-25  11164.000000    0.002821  10640.186133  10518.007446       1.0
# ...                  ...         ...           ...           ...       ...
# 2020-03-25  21200.599609    0.023941  26554.414102  25694.136514       1.0
# 2020-03-26  22552.199219    0.063753  26426.664102  25680.543506       1.0
# 2020-03-27  21636.800781   -0.040590  26278.796133  25661.419014      -1.0
# 2020-03-30  22327.500000    0.031922  26139.394141  25644.881514       1.0
# 2020-03-31  21917.199219   -0.018376  25990.776133  25623.566006      -1.0
#
#             Strategy_ret      Strategy
# Date
# ...

# %%
summary_ann(df[['DJI_Return','Strategy_ret']])
# Out:
#                 Return      Risk
# DJI_Return    0.091666  0.173956
# Strategy_ret  1.674659  0.138421

# %%
df[['DJI_Close','Strategy']].plot(logy=True)
plt.title('ifyou knew the future strategy')
# Out:
# Text(0.5, 1.0, 'ifyou knew the future strategy')
