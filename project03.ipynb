# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns=30

# %%
df=pd.read_csv('../jupyter/environment/movies_metadata.csv',low_memory=False)

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45461          0.0     90.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
# [45466 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
df.genres[0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
df.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
df.adult.value_counts()
# Out:
# adult
# False                                                                                                                             45454
# True                                                                                                                                  9
#  - Written by Ørnås                                                                                                                   1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: count, dtype: int64

# %%
df.drop(columns=['adult'],inplace=True)

# %%
df.drop(columns=['imdb_id'],inplace=True)

# %%
df.drop(columns=['original_title'],inplace=True)

# %%
df.drop(columns=['video'],inplace=True)

# %%
df.drop(columns=['homepage'],inplace=True)

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464                                                 []  227506
# 45465                                                 []  461257
#
#       original_language                                           overview  \
# 0                    en  Led by Woody, Andy's toys live happily in his ...
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45461                fa        Rising and falling between a man and woman.
# 45462                tl  An artist struggles to finish his work while a...
# 45463                en  When one of her hits goes wrong, a professiona...
# 45464                en  In a small town live two brothers, one a minis...
# 45465                en  50 years after decriminalisation of homosexual...
#
#       popularity                       poster_path  \
# 0      21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2        11.7129  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3       3.859495  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4       8.387519  /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...          ...                               ...
# 45461   0.072051  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462   0.178241  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463   0.903007  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464   0.003503  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465   0.163015  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45461          0.0     90.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           0.0         0.0
# 45465                     Queerama           0.0         0.0
#
# [45466 rows x 19 columns]

# %%
import json

# %%
import ast

# %%
df.columns
# Out:
# Index(['belongs_to_collection', 'budget', 'genres', 'id', 'original_language',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
json_col=['belongs_to_collection','genres','production_companies','spoken_languages']

# %%
df.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
df.genres.apply(lambda x: json.loads(x.replace("'",'"')))[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
df.genres.apply(ast.literal_eval)
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
df.genres=df.genres.apply(ast.literal_eval)

# %%
df.loc[:,json_col].apply(ast.literal_eval,axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.loc[:,json_col].apply(ast.literal_eval,axis=0)
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# File /usr/lib/python3.10/ast.py:108, in literal_eval(node_or_string)
#     106                 return left - right
#     107     return _convert_signed_num(node)
# --> 108 return _convert(node_or_string)
#
# File /usr/lib/python3.10/ast.py:107, in literal_eval.<locals>._convert(node)
#     105         else:
#     106             return left - right
# --> 107 return _convert_signed_num(node)
#
# File /usr/lib/python3.10/ast.py:81, in literal_eval.<locals>._convert_signed_num(node)
#      79     else:
#      80         return - operand
# ---> 81 return _convert_num(node)
#
# File /usr/lib/python3.10/ast.py:72, in literal_eval.<locals>._convert_num(node)
#      70 def _convert_num(node):
#      71     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 72         _raise_malformed_node(node)
#      73     return node.value
#
# File /usr/lib/python3.10/ast.py:69, in literal_eval.<locals>._raise_malformed_node(node)
#      67 if lno := getattr(node, 'lineno', None):
#      68     msg += f' on line {lno}'
# ---> 69 raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string: 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
df.belongs_to_collection=df.belongs_to_collection.apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)

# %%
df.spoken_languages=df.spoken_languages.apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)

# %%
df.spoken_languages
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45466, dtype: object

# %%
df.production_companies=df.production_companies.apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)

# %%
df.production_countries=df.production_countries.apply(lambda x: ast.literal_eval(x) if isinstance(x,str) else np.nan)

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464                                                 []  227506
# 45465                                                 []  461257
#
#       original_language                                           overview  \
# 0                    en  Led by Woody, Andy's toys live happily in his ...
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45461                fa        Rising and falling between a man and woman.
# 45462                tl  An artist struggles to finish his work while a...
# 45463                en  When one of her hits goes wrong, a professiona...
# 45464                en  In a small town live two brothers, one a minis...
# 45465                en  50 years after decriminalisation of homosexual...
#
#       popularity                       poster_path  \
# 0      21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2        11.7129  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3       3.859495  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4       8.387519  /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...          ...                               ...
# 45461   0.072051  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462   0.178241  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463   0.903007  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464   0.003503  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465   0.163015  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45461          0.0     90.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           0.0         0.0
# 45465                     Queerama           0.0         0.0
#
# [45466 rows x 19 columns]

# %%
 df.belongs_to_collection[0]['name']
# Out:
# 'Toy Story Collection'

# %%
df.belongs_to_collection=df.belongs_to_collection.apply(lambda x: x['name'] if isinstance(x,dict) else np.nan)

# %%
df.belongs_to_collection.value_counts(dropna=False)
# Out:
# belongs_to_collection
# NaN                              40975
# The Bowery Boys                     29
# Totò Collection                     27
# James Bond Collection               26
# Zatôichi: The Blind Swordsman       26
#                                  ...
# Glass Tiger collection               1
# Kathleen Madigan Collection          1
# The Big Bottom Box                   1
# Joséphine - Saga                     1
# Red Lotus Collection                 1
# Name: count, Length: 1696, dtype: int64

# %%
df.genres[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
for i in df.genres[0]:
    print(i['name'])
# Out:
# Animation
# Comedy
# Family

# %%
df.genres=df.genres.apply(lambda x: '|'.join(i['name'] for i in x))

# %%
df.genres.value_counts(dropna=False)
# Out:
# genres
# Drama                              5000
# Comedy                             3621
# Documentary                        2723
#                                    2442
# Drama|Romance                      1301
#                                    ...
# Action|Drama|Comedy|Documentary       1
# War|Drama|History|Thriller            1
# Horror|Drama|History|Thriller         1
# Comedy|Crime|Action|Drama             1
# Family|Animation|Romance|Comedy       1
# Name: count, Length: 4069, dtype: int64

# %%
df.genres.replace('',np.nan,inplace=True)

# %%
df.spoken_languages[1]
# Out:
# [{'iso_639_1': 'en', 'name': 'English'},
#  {'iso_639_1': 'fr', 'name': 'Français'}]

# %%
df.spoken_languages=df.spoken_languages.apply(lambda x: '|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
df.spoken_languages.value_counts(dropna=False)
# Out:
# spoken_languages
# English                           22395
#                                    3952
# Français                           1853
# 日本語                                1289
# Italiano                           1218
#                                   ...
# English|日本語|Latin                     1
# Deutsch||ελληνικά|English             1
# English|suomi|Deutsch|svenska         1
# English|Français|Deutsch|فارسی        1
# Fulfulde|English                      1
# Name: count, Length: 1843, dtype: int64

# %%
df.spoken_languages.replace('',np.nan,inplace=True)

# %%
df.production_countries
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45466, dtype: object

# %%
df.production_countries=df.production_countries.apply(lambda x: '|'.join(i['name'] for i in x)if isinstance(x,list) else np.nan)

# %%
df.production_countries.value_counts(dropna=False)
# Out:
# production_countries
# United States of America                  17851
#                                            6282
# United Kingdom                             2238
# France                                     1654
# Japan                                      1356
#                                           ...
# Romania|United Kingdom|Canada                 1
# Finland|Germany|Netherlands                   1
# France|Denmark|Spain|Sweden                   1
# France|United States of America|Canada        1
# Egypt|Italy|United States of America          1
# Name: count, Length: 2391, dtype: int64

# %%
df.production_countries.replace('',np.nan,inplace=True)

# %%
df.production_companies[2]
# Out:
# [{'name': 'Warner Bros.', 'id': 6194}, {'name': 'Lancaster Gate', 'id': 19464}]

# %%
df.production_companies=df.production_companies.apply(lambda x: '|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
df.production_companies.value_counts(dropna=False)
# Out:
# production_companies
# NaN                                                                                                                                           11881
# Metro-Goldwyn-Mayer (MGM)                                                                                                                       742
# Warner Bros.                                                                                                                                    540
# Paramount Pictures                                                                                                                              505
# Twentieth Century Fox Film Corporation                                                                                                          439
#                                                                                                                                               ...
# HBO Films|Moving Pictures                                                                                                                         1
# BIM Distribuzione|Canal+|Alta Producción|Centre National de la Cinématographie (CNC)|Rézo Productions|Compagnie Eric Rohmer (CER)|Cinémage        1
# Galatée Films|Novo Arturo Films|Constantin Film Produktion|Pathé|France 2 Cinéma|France 3 Cinema|Logline Studios|Blue Screen Productions          1
# Fox Searchlight Pictures|26 Films                                                                                                                 1
# Yermoliev                                                                                                                                         1
# Name: count, Length: 22672, dtype: int64

# %%
df.production_companies.replace('',np.nan,inplace=True)

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40975
# budget                       0
# genres                    2442
# id                           0
# original_language           11
# overview                   954
# popularity                   5
# poster_path                386
# production_companies     11881
# production_countries      6288
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages          3958
# status                      87
# tagline                  25054
# title                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
pd.read_csv('../jupyter/environment/movies_metadata.csv',low_memory=False).isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45466 non-null  object
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       41508 non-null  object
#  14  status                 45379 non-null  object
#  15  tagline                20412 non-null  object
#  16  title                  45460 non-null  object
#  17  vote_average           45460 non-null  float64
#  18  vote_count             45460 non-null  float64
# dtypes: float64(4), object(15)
# memory usage: 6.6+ MB

# %%
df.budget.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df.budget.astype('float')
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/internals/blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:187, in astype_array(values, dtype, copy)
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
# --> 187     values = _astype_nansafe(values, dtype, copy=copy)
#     189 # in pandas we don't store numpy str dtypes, so convert to object
#     190 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/jupyter/environment/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:138, in _astype_nansafe(arr, dtype, copy, skipna)
#     134     raise ValueError(msg)
#     136 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     137     # Explicit copy, or required since NumPy can't view from / to object.
# --> 138     return arr.astype(dtype, copy=True)
#     140 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '/ff9qCepilowshEtG2GYWwzt2bs4.jpg'

# %%
df.budget
# Out:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45466, dtype: object

# %%
df.budget=pd.to_numeric(df.budget,errors='coerce')

# %%
df.budget.value_counts(dropna=False)
# Out:
# budget
# NaN            36576
# 5000000.0        286
# 10000000.0       259
# 20000000.0       243
# 2000000.0        242
#                ...
# 270000000.0        1
# 923.0              1
# 72500000.0         1
# 2160000.0          1
# 1254040.0          1
# Name: count, Length: 1223, dtype: int64

# %%
df.budget.replace(0,np.nan,inplace=True)

# %%
df.budget=df.budget.div(1000000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 8890 non-null   float64
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       41508 non-null  object
#  14  status                 45379 non-null  object
#  15  tagline                20412 non-null  object
#  16  title                  45460 non-null  object
#  17  vote_average           45460 non-null  float64
#  18  vote_count             45460 non-null  float64
# dtypes: float64(5), object(14)
# memory usage: 6.6+ MB

# %%
df.revenue.value_counts(dropna=False)
# Out:
# revenue
# 0.0           38052
# 12000000.0       20
# 10000000.0       19
# 11000000.0       19
# 2000000.0        18
#               ...
# 36565280.0        1
# 439564.0          1
# 35610100.0        1
# 10217873.0        1
# 1413000.0         1
# Name: count, Length: 6864, dtype: int64

# %%
df.revenue.replace(0,np.nan,inplace=True)

# %%
df.revenue=df.revenue.div(1000000)

# %%
df.rename(columns={'revenue':'revenue_musd','budget':'budget_musd'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            8890 non-null   float64
#  2   genres                 43024 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       41508 non-null  object
#  14  status                 45379 non-null  object
#  15  tagline                20412 non-null  object
#  16  title                  45460 non-null  object
#  17  vote_average           45460 non-null  float64
#  18  vote_count             45460 non-null  float64
# dtypes: float64(5), object(14)
# memory usage: 6.6+ MB

# %%
df.runtime
# Out:
# 0         81.0
# 1        104.0
# 2        101.0
# 3        127.0
# 4        106.0
#          ...
# 45461     90.0
# 45462    360.0
# 45463     90.0
# 45464     87.0
# 45465     75.0
# Name: runtime, Length: 45466, dtype: float64

# %%
df.runtime.value_counts(dropna=False)
# Out:
# runtime
# 90.0     2556
# 0.0      1558
# 100.0    1470
# 95.0     1412
# 93.0     1214
#          ...
# 410.0       1
# 283.0       1
# 238.0       1
# 566.0       1
# 780.0       1
# Name: count, Length: 354, dtype: int64

# %%
df.runtime.replace(0,np.nan,inplace=True)

# %%
df.id=pd.to_numeric(df.id,errors='coerce')

# %%
df.id.value_counts(dropna=False).head(30)
# Out:
# id
# NaN         3
# 141971.0    3
# 11115.0     2
# 25541.0     2
# 15028.0     2
# 132641.0    2
# 84198.0     2
# 13209.0     2
# 77221.0     2
# 152795.0    2
# 12600.0     2
# 10991.0     2
# 42495.0     2
# 14788.0     2
# 18440.0     2
# 168538.0    2
# 105045.0    2
# 159849.0    2
# 22649.0     2
# 4912.0      2
# 5511.0      2
# 97995.0     2
# 265189.0    2
# 110428.0    2
# 99080.0     2
# 69234.0     2
# 298721.0    2
# 109962.0    2
# 119916.0    2
# 23305.0     2
# Name: count, dtype: int64

# %%
df.popularity
# Out:
# 0        21.946943
# 1        17.015539
# 2          11.7129
# 3         3.859495
# 4         8.387519
#            ...
# 45461     0.072051
# 45462     0.178241
# 45463     0.903007
# 45464     0.003503
# 45465     0.163015
# Name: popularity, Length: 45466, dtype: object

# %%
df.popularity=pd.to_numeric(df.popularity,errors='coerce')

# %%
df.popularity.value_counts(dropna=False)
# Out:
# popularity
# 0.000000    66
# 0.000001    56
# 0.000308    43
# 0.000220    40
# 0.000844    38
#             ..
# 4.762242     1
# 6.173752     1
# 0.645652     1
# 0.556292     1
# 0.163015     1
# Name: count, Length: 43758, dtype: int64

# %%
df.popularity=df.popularity.astype('float')

# %%
df.popularity
# Out:
# 0        21.946943
# 1        17.015539
# 2        11.712900
# 3         3.859495
# 4         8.387519
#            ...
# 45461     0.072051
# 45462     0.178241
# 45463     0.903007
# 45464     0.003503
# 45465     0.163015
# Name: popularity, Length: 45466, dtype: float64

# %%
df.popularity.replace(0,np.nan,inplace=True)

# %%
df.vote_count.value_counts(dropna=False).tail(20)
# Out:
# vote_count
# 1269.0    1
# 957.0     1
# 2169.0    1
# 1276.0    1
# 694.0     1
# 2000.0    1
# 804.0     1
# 2519.0    1
# 3759.0    1
# 781.0     1
# 448.0     1
# 1059.0    1
# 1721.0    1
# 865.0     1
# 1383.0    1
# 2755.0    1
# 1187.0    1
# 4200.0    1
# 3322.0    1
# 2712.0    1
# Name: count, dtype: int64

# %%
df.vote_count.isna().sum()
# Out:
# 6

# %%
df.vote_average.value_counts(dropna=False)
# Out:
# vote_average
# NaN    3004
# 6.0    2468
# 5.0    2001
# 7.0    1886
# 6.5    1722
#        ...
# 9.4       3
# 9.6       1
# 9.8       1
# 0.7       1
# 1.1       1
# Name: count, Length: 92, dtype: int64

# %%
df.vote_average.replace(0,np.nan,inplace=True)

# %%
df.loc[df.vote_count==0,'vote_average']=np.nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            8890 non-null   float64
#  2   genres                 43024 non-null  object
#  3   id                     45463 non-null  float64
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45394 non-null  float64
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
#  14  status                 45379 non-null  object
#  15  tagline                20412 non-null  object
#  16  title                  45460 non-null  object
#  17  vote_average           42462 non-null  float64
#  18  vote_count             45460 non-null  float64
# dtypes: float64(7), object(12)
# memory usage: 6.6+ MB

# %%
df.release_date
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45461           NaN
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45466, dtype: object

# %%
df.release_date=pd.to_datetime(df.release_date,errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget_musd            8890 non-null   float64
#  2   genres                 43024 non-null  object
#  3   id                     45463 non-null  float64
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45394 non-null  float64
#  7   poster_path            45080 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45376 non-null  datetime64[ns]
#  11  revenue_musd           7408 non-null   float64
#  12  runtime                43645 non-null  float64
#  13  spoken_languages       41508 non-null  object
#  14  status                 45379 non-null  object
#  15  tagline                20412 non-null  object
#  16  title                  45460 non-null  object
#  17  vote_average           42462 non-null  float64
#  18  vote_count             45460 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(11)
# memory usage: 6.6+ MB

# %%
df.release_date.value_counts(dropna=False)
# Out:
# release_date
# 2008-01-01    136
# 2009-01-01    121
# 2007-01-01    118
# 2005-01-01    111
# 2006-01-01    101
#              ...
# 1957-09-26      1
# 1938-11-21      1
# 1936-08-19      1
# 2010-01-27      1
# 1917-10-21      1
# Name: count, Length: 17334, dtype: int64

# %%
df.original_language
# Out:
# 0        en
# 1        en
# 2        en
# 3        en
# 4        en
#          ..
# 45461    fa
# 45462    tl
# 45463    en
# 45464    en
# 45465    en
# Name: original_language, Length: 45466, dtype: object

# %%
df.original_language.value_counts(dropna=False)
# Out:
# original_language
# en       32269
# fr        2438
# it        1529
# ja        1350
# de        1080
#          ...
# zu           1
# qu           1
# 104.0        1
# la           1
# si           1
# Name: count, Length: 93, dtype: int64

# %%
df.title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45461                         Subdue
# 45462            Century of Birthing
# 45463                       Betrayal
# 45464               Satan Triumphant
# 45465                       Queerama
# Name: title, Length: 45466, dtype: object

# %%
df.title.value_counts(dropna=False)
# Out:
# title
# Cinderella              11
# Alice in Wonderland      9
# Hamlet                   9
# Les Misérables           8
# Beauty and the Beast     8
#                         ..
# Cluny Brown              1
# Babies                   1
# The Green Room           1
# Captain Conan            1
# Queerama                 1
# Name: count, Length: 42278, dtype: int64

# %%
df.overview.value_counts(dropna=False).head(10)
# Out:
# overview
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1102
# Recovering from a nail gun shot to the head and 13 months of coma, doctor Pekka Valinta starts to unravel the mystery of his past, still suffering from total amnesia.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   3
# A few funny little novels about different aspects of life.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               3
# King Lear, old and tired, divides his kingdom among his daughters, giving great importance to their protestations of love for him. When Cordelia, youngest and most honest, refuses to idly flatter the old man in return for favor, he banishes her and turns for support to his remaining daughters. But Goneril and Regan have no love for him and instead plot to take all his power from him. In a parallel, Lear's loyal courtier Gloucester favors his illegitimate son Edmund after being told lies about his faithful son Edgar. Madness and tragedy befall both ill-starred fathers.                                                           3
# Released                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 3
# Adaptation of the Jane Austen novel.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     3
# Ten years into a marriage, the wife is disappointed by the husband's lack of financial success, meaning she has to work and can't treat herself and the husband finds the wife slovenly and mean-spirited: she neither cooks not cleans particularly well and is generally disagreeable. In turn, he alternately ignores her and treats her as a servant. Neither is particularly happy, not helped by their unsatisfactory lodgers. The husband is easily seduced by an ex-colleague, a widow with a small child who needs some security, and considers leaving his wife.                                                                               2
# Since women are banned from soccer matches, Iranian females masquerade as males so they can slip into Tehran's stadium to see the game between Iran and Bahrain. The ones who are caught and arrested are taken to a holding area and guarded by soldiers. One sympathetic soldier agrees to watch the game through a peephole and recount the action to the impatient fans.                                                                                                                                                                                                                                                                             2
# Winter, 1915. Confined by her family to an asylum in the South of France - where she will never sculpt again - the chronicle of Camille Claudel's reclusive life, as she waits for a visit from her brother, Paul Claudel.                                                                                                                                                                                                                                                                                                                                                                                                                               2
# Count de Chagnie has discovered Christine's singing talent on a market place and sent her to his friend Carriere, the director of the Parisian opera. However just when she arrives Carriere's dismissed. His arrogant successor refuses to let a woman of low birth sing in his opera, but graciously employs Christine as gadrobiere for his wife Charlotta, who's installed as first singer. He also fights the phantom, an unknown guy who lives since many years in the catacombs below the opera and was granted privileges by Carriere. However the phantom knows how to defend himself and at the same time helps Christine to her career.       2
# Name: count, dtype: int64

# %%
df.overview.replace(' ',np.nan,inplace=True)

# %%
df.overview.replace('No overview found.',np.nan,inplace=True)

# %%
df.overview.replace('No Overview',np.nan,inplace=True)

# %%
df.overview.replace('No movie overview available.',np.nan,inplace=True)

# %%
df.tagline.value_counts(dropna=False).head(10)
# Out:
# tagline
# NaN                                   25058
# Based on a true story.                    7
# Trust no one.                             4
# Be careful what you wish for.             4
# Who is John Galt?                         3
# Some doors should never be opened.        3
# Drama                                     3
# Documentary                               3
# There is no turning back                  3
# The end is near.                          3
# Name: count, dtype: int64

# %%
df.tagline.replace('-',np.nan,inplace=True)

# %%
df[df.duplicated(keep=False)].sort_values(by='id')
# Out:
# Empty DataFrame
# Columns: [belongs_to_collection, budget_musd, genres, id, original_language, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue_musd, runtime, spoken_languages, status, tagline, title, vote_average, vote_count]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated(subset='id',keep=False)].sort_values(by='id')
# Out:
#       belongs_to_collection  budget_musd  \
# 33826                   NaN    30.000000
# 5865                    NaN    30.000000
# 4114     Pokémon Collection    16.000000
# 44821    Pokémon Collection    16.000000
# 44826    Pokémon Collection          NaN
# 5535     Pokémon Collection          NaN
# 15765                   NaN     0.002500
# 11342                   NaN     0.002500
# 10419                   NaN     1.600000
# 12066                   NaN     1.600000
# 5130                    NaN    26.000000
# 33743                   NaN    26.000000
# 949                     NaN     0.000004
# 15074                   NaN     0.000004
# 9576                    NaN    10.000000
# 26625                   NaN    10.000000
# 20843                   NaN    40.000000
# 11155                   NaN    40.000000
# 21116                   NaN          NaN
# 2564                    NaN          NaN
# 20899                   NaN          NaN
# 5710                    NaN          NaN
# 23534                   NaN     3.512454
# 4356                    NaN     3.512454
# 30001                   NaN          NaN
# 838                     NaN          NaN
# 19730                   NaN          NaN
# 29503                   NaN          NaN
# 35587                   NaN          NaN
#
#                                                   genres        id  \
# 33826                Comedy|Crime|Drama|Romance|Thriller    4912.0
# 5865                 Comedy|Crime|Drama|Romance|Thriller    4912.0
# 4114           Adventure|Fantasy|Animation|Action|Family   10991.0
# 44821          Adventure|Fantasy|Animation|Action|Family   10991.0
# 44826  Adventure|Fantasy|Animation|Science Fiction|Fa...   12600.0
# 5535   Adventure|Fantasy|Animation|Science Fiction|Fa...   12600.0
# 15765                               Drama|Comedy|Foreign   13209.0
# 11342                               Drama|Comedy|Foreign   13209.0
# 10419                                Drama|Crime|Mystery   14788.0
# 12066                                Drama|Crime|Mystery   14788.0
# 5130           Adventure|Family|Science Fiction|Thriller   15028.0
# 33743          Adventure|Family|Science Fiction|Thriller   15028.0
# 949                                    Drama|Romance|War   22649.0
# 15074                                  Drama|Romance|War   22649.0
# 9576                 Drama|Horror|Music|Romance|TV Movie   69234.0
# 26625                Drama|Horror|Music|Romance|TV Movie   69234.0
# 20843                                    Adventure|Drama   77221.0
# 11155                                    Adventure|Drama   77221.0
# 21116                                        Documentary   84198.0
# 2564                                         Documentary   84198.0
# 20899                                              Drama  109962.0
# 5710                                               Drama  109962.0
# 23534                                              Drama  110428.0
# 4356                                               Drama  110428.0
# 30001                                              Drama  132641.0
# 838                                                Drama  132641.0
# 19730  Carousel Productions|Vision View Entertainment...       NaN
# 29503  Aniplex|GoHands|BROSTA TV|Mardock Scramble Pro...       NaN
# 35587  Odyssey Media|Pulser Productions|Rogue State|T...       NaN
#
#       original_language                                           overview  \
# 33826                en  Television made him famous, but his biggest hi...
# 5865                 en  Television made him famous, but his biggest hi...
# 4114                 ja  When Molly Hale's sadness of her father's disa...
# 44821                ja  When Molly Hale's sadness of her father's disa...
# 44826                ja  All your favorite Pokémon characters are back,...
# 5535                 ja  All your favorite Pokémon characters are back,...
# 15765                fa  Since women are banned from soccer matches, Ir...
# 11342                fa  Since women are banned from soccer matches, Ir...
# 10419                en  Set against the backdrop of a decaying Midwest...
# 12066                en  Set against the backdrop of a decaying Midwest...
# 5130                 en  Until now, Zak Gibbs' greatest challenge has b...
# 33743                en  Until now, Zak Gibbs' greatest challenge has b...
# 949                  en  British nurse Catherine Barkley (Helen Hayes) ...
# 15074                en  British nurse Catherine Barkley (Helen Hayes) ...
# 9576                 en  Count de Chagnie has discovered Christine's si...
# 26625                en  Count de Chagnie has discovered Christine's si...
# 20843                en  On the Arabian Peninsula in the 1930s, two war...
# 11155                en  On the Arabian Peninsula in the 1930s, two war...
# 21116                en  Using personal stories, this powerful document...
# 2564                 en  Using personal stories, this powerful document...
# 20899                en  Two literary women compete for 20 years: one w...
# 5710                 en  Two literary women compete for 20 years: one w...
# 23534                fr  Winter, 1915. Confined by her family to an asy...
# 4356                 fr  Winter, 1915. Confined by her family to an asy...
# 30001                ja  Ten years into a marriage, the wife is disappo...
# 838                  ja  Ten years into a marriage, the wife is disappo...
# 19730             104.0                                           Released
# 29503              68.0                                           Released
# 35587              82.0                                           Released
#
#        popularity                          poster_path  \
# 33826    7.645827     /o3Im9nPLAgtlw1j2LtpMebAotSe.jpg
# 5865    11.331072     /o3Im9nPLAgtlw1j2LtpMebAotSe.jpg
# 4114    10.264597     /5ILjS6XB5deiHop8SXPsYxXWVPE.jpg
# 44821    6.480376     /5ILjS6XB5deiHop8SXPsYxXWVPE.jpg
# 44826    6.080108     /bqL0PVHbQ8Jmw3Njcl38kW0CoeM.jpg
# 5535     7.072301     /bqL0PVHbQ8Jmw3Njcl38kW0CoeM.jpg
# 15765    1.529879     /nfkOkpudNNIjRrf0mTFVoiGzHyc.jpg
# 11342    1.528960     /nfkOkpudNNIjRrf0mTFVoiGzHyc.jpg
# 10419    3.185256     /w56oo9nREcF54sNXVYuE9QxZFjT.jpg
# 12066    3.008299     /w56oo9nREcF54sNXVYuE9QxZFjT.jpg
# 5130     5.373623     /xGhDPrBz9mJN8CsIjA23jQSd3sc.jpg
# 33743    4.920175     /xGhDPrBz9mJN8CsIjA23jQSd3sc.jpg
# 949      1.914697     /k0MF0IIbJ2PfOIku2KyraXL72d8.jpg
# 15074    2.411191     /k0MF0IIbJ2PfOIku2KyraXL72d8.jpg
# 9576     0.441872     /ole8e9YQwvHoKVpWO0lgfLFFemc.jpg
# 26625    0.438490     /ole8e9YQwvHoKVpWO0lgfLFFemc.jpg
# 20843    6.475665     /iQd7zWhSeCe3cgdPcLIDXjGfdzL.jpg
# 11155    6.652197     /iQd7zWhSeCe3cgdPcLIDXjGfdzL.jpg
# 21116    1.673307     /jn8L1QdWWX5c0NUOLjzaSXtZrbt.jpg
# 2564     0.501046     /jn8L1QdWWX5c0NUOLjzaSXtZrbt.jpg
# 20899   10.396878     /tOflyY8eUFWubLKJH7fKg4KwpCl.jpg
# 5710    12.180836     /tOflyY8eUFWubLKJH7fKg4KwpCl.jpg
# 23534    0.110065     /sGMPDg6je1zKi0TiX9b4pP6yN02.jpg
# 4356     0.134014     /sGMPDg6je1zKi0TiX9b4pP6yN02.jpg
# 30001    0.619388     /z9WiHt5uQjs8L8tyBpRBKzlheF2.jpg
# 838      0.096079     /z9WiHt5uQjs8L8tyBpRBKzlheF2.jpg
# 19730         NaN                         Midnight Man
# 29503         NaN  Mardock Scramble: The Third Exhaust
# 35587         NaN                     Avalanche Sharks
#
#                                     production_companies  \
# 33826         Miramax Films|Allied Filmmakers|Mad Chance
# 5865          Miramax Films|Allied Filmmakers|Mad Chance
# 4114   TV Tokyo|4 Kids Entertainment|Nintendo|Pikachu...
# 44821  TV Tokyo|4 Kids Entertainment|Nintendo|Pikachu...
# 44826                                                NaN
# 5535                                                 NaN
# 15765                      Jafar Panahi Film Productions
# 11342                      Jafar Panahi Film Productions
# 10419                    Magnolia Pictures|Extension 765
# 12066                    Magnolia Pictures|Extension 765
# 5130   Paramount Pictures|Nickelodeon Movies|Valhalla...
# 33743  Paramount Pictures|Nickelodeon Movies|Valhalla...
# 949                                   Paramount Pictures
# 15074                                 Paramount Pictures
# 9576   Beta Film|Reteitalia|TF1|Hexatel|Saban/Scheric...
# 26625  Beta Film|Reteitalia|TF1|Hexatel|Saban/Scheric...
# 20843  France 2 Cinéma|Quinta Communications|Carthago...
# 11155  France 2 Cinéma|Quinta Communications|Carthago...
# 21116                                                NaN
# 2564                                                 NaN
# 20899                   Metro-Goldwyn-Mayer (MGM)|Jaquet
# 5710                    Metro-Goldwyn-Mayer (MGM)|Jaquet
# 23534  Canal+|Arte France Cinéma|3B Productions|C.R.R...
# 4356   Canal+|Arte France Cinéma|3B Productions|C.R.R...
# 30001                                       Toho Company
# 838                                         Toho Company
# 19730                                                NaN
# 29503                                                NaN
# 35587                                                NaN
#
#                                 production_countries release_date  \
# 33826                       United States of America   2002-12-30
# 5865                        United States of America   2002-12-30
# 4114                                           Japan   2000-07-08
# 44821                                          Japan   2000-07-08
# 44826                 Japan|United States of America   2001-07-06
# 5535                  Japan|United States of America   2001-07-06
# 15765                                           Iran   2006-05-26
# 11342                                           Iran   2006-05-26
# 10419                       United States of America   2005-09-03
# 12066                       United States of America   2005-09-03
# 5130                        United States of America   2002-03-17
# 33743                       United States of America   2002-03-17
# 949                         United States of America   1932-12-08
# 15074                       United States of America   1932-12-08
# 9576   France|Germany|Italy|United States of America   1990-03-18
# 26625  France|Germany|Italy|United States of America   1990-03-18
# 20843                     France|Italy|Qatar|Tunisia   2011-12-21
# 11155                     France|Italy|Qatar|Tunisia   2011-12-21
# 21116                       United States of America   2012-03-22
# 2564                        United States of America   2012-03-22
# 20899                       United States of America   1981-09-23
# 5710                        United States of America   1981-09-23
# 23534                                         France   2013-03-13
# 4356                                          France   2013-03-13
# 30001                                          Japan   1953-04-29
# 838                                            Japan   1953-04-29
# 19730                                            NaN          NaT
# 29503                                            NaN          NaT
# 35587                                            NaN          NaT
#
#        revenue_musd  runtime  spoken_languages    status  \
# 33826     33.013805    113.0           English  Released
# 5865      33.013805    113.0           English  Released
# 4114      68.411275     93.0           English  Released
# 44821     68.411275     93.0           English  Released
# 44826     28.023563     75.0               日本語  Released
# 5535      28.023563     75.0               日本語  Released
# 15765           NaN     93.0             فارسی  Released
# 11342           NaN     93.0             فارسی  Released
# 10419           NaN     73.0           English  Released
# 12066           NaN     73.0           English  Released
# 5130      38.793283     94.0     Český|English  Released
# 33743     38.793283     94.0     Český|English  Released
# 949        0.000025     89.0           English  Released
# 15074      0.000025     89.0           English  Released
# 9576            NaN    168.0  English|Italiano  Released
# 26625           NaN    168.0  English|Italiano  Released
# 20843      5.446000    130.0           English  Released
# 11155      5.446000    130.0           English  Released
# 21116           NaN     84.0           English  Released
# 2564            NaN     84.0           English  Released
# 20899           NaN    115.0           English  Released
# 5710            NaN    115.0           English  Released
# 23534      0.115860     95.0          Français  Released
# 4356       0.115860     95.0          Français  Released
# 30001           NaN     89.0               日本語  Released
# 838             NaN     89.0               日本語  Released
# 19730           NaN      NaN               NaN       NaN
# 29503           NaN      NaN               NaN       NaN
# 35587           NaN      NaN               NaN       NaN
#
#                                                  tagline  \
# 33826            Some things are better left top secret.
# 5865             Some things are better left top secret.
# 4114                       Pokémon: Spell of the Unknown
# 44821                      Pokémon: Spell of the Unknown
# 44826                                                NaN
# 5535                                                 NaN
# 15765                                                NaN
# 11342                                                NaN
# 10419                                                NaN
# 12066                                                NaN
# 5130   The adventure of a lifetime, in a few mere sec...
# 33743  The adventure of a lifetime, in a few mere sec...
# 949            Every woman who has loved will understand
# 15074          Every woman who has loved will understand
# 9576                                                 NaN
# 26625                                                NaN
# 20843                                                NaN
# 11155                                                NaN
# 21116                              One Nation. Underfed.
# 2564                               One Nation. Underfed.
# 20899  From the very beginning, they knew they'd be f...
# 5710   From the very beginning, they knew they'd be f...
# 23534                                                NaN
# 4356                                                 NaN
# 30001                                                NaN
# 838                                                  NaN
# 19730                                                NaN
# 29503                                                NaN
# 35587                                                NaN
#
#                                              title  vote_average  vote_count
# 33826              Confessions of a Dangerous Mind           6.6       281.0
# 5865               Confessions of a Dangerous Mind           6.6       281.0
# 4114                 Pokémon: Spell of the Unknown           6.0       143.0
# 44821                Pokémon: Spell of the Unknown           6.0       144.0
# 44826  Pokémon 4Ever: Celebi - Voice of the Forest           5.7        82.0
# 5535   Pokémon 4Ever: Celebi - Voice of the Forest           5.7        82.0
# 15765                                      Offside           6.7        27.0
# 11342                                      Offside           6.7        27.0
# 10419                                       Bubble           6.4        36.0
# 12066                                       Bubble           6.4        36.0
# 5130                                 Clockstoppers           4.9        89.0
# 33743                                Clockstoppers           4.9        90.0
# 949                             A Farewell to Arms           6.2        29.0
# 15074                           A Farewell to Arms           6.2        29.0
# 9576                      The Phantom of the Opera           5.0         3.0
# 26625                     The Phantom of the Opera           5.0         3.0
# 20843                                   Black Gold           5.9        77.0
# 11155                                   Black Gold           5.9        77.0
# 21116                         A Place at the Table           6.9         7.0
# 2564                          A Place at the Table           6.9         7.0
# 20899                              Rich and Famous           4.9         7.0
# 5710                               Rich and Famous           4.9         7.0
# 23534                         Camille Claudel 1915           7.0        20.0
# 4356                          Camille Claudel 1915           7.0        20.0
# 30001                                         Wife           NaN         0.0
# 838                                           Wife           NaN         0.0
# 19730                                          NaN           NaN         NaN
# 29503                                          NaN           NaN         NaN
# 35587                                          NaN           NaN         NaN

# %%
df.drop_duplicates(subset='id',inplace=True)

# %%
df.id.value_counts(dropna=False)
# Out:
# id
# 862.0       1
# 74458.0     1
# 296206.0    1
# 107308.0    1
# 16247.0     1
#            ..
# 44399.0     1
# 10138.0     1
# 32084.0     1
# 42191.0     1
# 461257.0    1
# Name: count, Length: 45434, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45434 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4488 non-null   object
#  1   budget_musd            8880 non-null   float64
#  2   genres                 42992 non-null  object
#  3   id                     45433 non-null  float64
#  4   original_language      45423 non-null  object
#  5   overview               44332 non-null  object
#  6   popularity             45364 non-null  float64
#  7   poster_path            45048 non-null  object
#  8   production_companies   33562 non-null  object
#  9   production_countries   39151 non-null  object
#  10  release_date           45346 non-null  datetime64[ns]
#  11  revenue_musd           7398 non-null   float64
#  12  runtime                43615 non-null  float64
#  13  spoken_languages       41480 non-null  object
#  14  status                 45349 non-null  object
#  15  tagline                20397 non-null  object
#  16  title                  45430 non-null  object
#  17  vote_average           42435 non-null  float64
#  18  vote_count             45430 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(11)
# memory usage: 6.9+ MB

# %%
df.isna().sum()/len(df)
# Out:
# belongs_to_collection    0.901219
# budget_musd              0.804552
# genres                   0.053748
# id                       0.000022
# original_language        0.000242
# overview                 0.024255
# popularity               0.001541
# poster_path              0.008496
# production_companies     0.261302
# production_countries     0.138289
# release_date             0.001937
# revenue_musd             0.837170
# runtime                  0.040036
# spoken_languages         0.087027
# status                   0.001871
# tagline                  0.551063
# title                    0.000088
# vote_average             0.066008
# vote_count               0.000088
# dtype: float64

# %%
df[df.title.isna()]
# Out:
#              belongs_to_collection  budget_musd  \
# 19729                          NaN          NaN
# 19730                          NaN          NaN
# 29502  Mardock Scramble Collection          NaN
# 35586                          NaN          NaN
#
#                                                   genres        id  \
# 19729                              Action|Thriller|Drama   82663.0
# 19730  Carousel Productions|Vision View Entertainment...       NaN
# 29502                          Animation|Science Fiction  122662.0
# 35586             TV Movie|Action|Horror|Science Fiction  249260.0
#
#       original_language                                           overview  \
# 19729                en  British soldiers force a recently captured IRA...
# 19730             104.0                                           Released
# 29502                ja         Third film of the Mardock Scramble series.
# 35586                en  A group of skiers are terrorized during spring...
#
#        popularity   poster_path production_companies production_countries  \
# 19729         NaN           NaN                  NaN                  NaN
# 19730         NaN  Midnight Man                  NaN                  NaN
# 29502         NaN           NaN                  NaN                  NaN
# 35586         NaN           NaN                  NaN                  NaN
#
#       release_date  revenue_musd  runtime spoken_languages status tagline  \
# 19729          NaT           NaN      NaN              NaN    NaN     NaN
# 19730          NaT           NaN      NaN              NaN    NaN     NaN
# 29502          NaT           NaN      NaN              NaN    NaN     NaN
# 35586          NaT           NaN      NaN              NaN    NaN     NaN
#
#       title  vote_average  vote_count
# 19729   NaN           NaN         NaN
# 19730   NaN           NaN         NaN
# 29502   NaN           NaN         NaN
# 35586   NaN           NaN         NaN

# %%
df.dropna(subset=['title','id'],inplace=True)

# %%
df.id=df.id.astype('int')

# %%
df.notna().sum(axis=1).value_counts()
# Out:
# 15    12499
# 16    11437
# 14     5445
# 17     4263
# 18     3859
# 13     3048
# 12     1887
# 19     1132
# 11     1028
# 10      510
# Name: count, dtype: int64

# %%
len(df.columns)
# Out:
# 19

# %%
idx=df[df.notna().sum(axis=1)<=6].index

# %%
df.drop(idx,axis=0,inplace=True)

# %%
df.dropna(thresh=10,axis=0,inplace=True)

# %%
df
# Out:
#                 belongs_to_collection  budget_musd                    genres  \
# 0                Toy Story Collection         30.0   Animation|Comedy|Family
# 1                                 NaN         65.0  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection          NaN            Romance|Comedy
# 3                                 NaN         16.0      Comedy|Drama|Romance
# 4      Father of the Bride Collection          NaN                    Comedy
# ...                               ...          ...                       ...
# 45461                             NaN          NaN              Drama|Family
# 45462                             NaN          NaN                     Drama
# 45463                             NaN          NaN     Action|Drama|Thriller
# 45464                             NaN          NaN                       NaN
# 45465                             NaN          NaN                       NaN
#
#            id original_language  \
# 0         862                en
# 1        8844                en
# 2       15602                en
# 3       31357                en
# 4       11862                en
# ...       ...               ...
# 45461  439050                fa
# 45462  111109                tl
# 45463   67758                en
# 45464  227506                en
# 45465  461257                en
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 45461        Rising and falling between a man and woman.    0.072051
# 45462  An artist struggles to finish his work while a...    0.178241
# 45463  When one of her hits goes wrong, a professiona...    0.903007
# 45464  In a small town live two brothers, one a minis...    0.003503
# 45465  50 years after decriminalisation of homosexual...    0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 45461                                                NaN
# 45462                                        Sine Olivia
# 45463                            American World Pictures
# 45464                                          Yermoliev
# 45465                                                NaN
#
#            production_countries release_date  revenue_musd  runtime  \
# 0      United States of America   1995-10-30    373.554033     81.0
# 1      United States of America   1995-12-15    262.797249    104.0
# 2      United States of America   1995-12-22           NaN    101.0
# 3      United States of America   1995-12-22     81.452156    127.0
# 4      United States of America   1995-02-10     76.578911    106.0
# ...                         ...          ...           ...      ...
# 45461                      Iran          NaT           NaN     90.0
# 45462               Philippines   2011-11-17           NaN    360.0
# 45463  United States of America   2003-08-01           NaN     90.0
# 45464                    Russia   1917-10-21           NaN     87.0
# 45465            United Kingdom   2017-06-09           NaN     75.0
#
#        spoken_languages    status  \
# 0               English  Released
# 1      English|Français  Released
# 2               English  Released
# 3               English  Released
# 4               English  Released
# ...                 ...       ...
# 45461             فارسی  Released
# 45462               NaN  Released
# 45463           English  Released
# 45464               NaN  Released
# 45465           English  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           NaN         0.0
# 45465                     Queerama           NaN         0.0
#
# [45108 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45108 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4487 non-null   object
#  1   budget_musd            8878 non-null   float64
#  2   genres                 42968 non-null  object
#  3   id                     45108 non-null  int64
#  4   original_language      45097 non-null  object
#  5   overview               44133 non-null  object
#  6   popularity             45081 non-null  float64
#  7   poster_path            44878 non-null  object
#  8   production_companies   33561 non-null  object
#  9   production_countries   39146 non-null  object
#  10  release_date           45072 non-null  datetime64[ns]
#  11  revenue_musd           7398 non-null   float64
#  12  runtime                43542 non-null  float64
#  13  spoken_languages       41459 non-null  object
#  14  status                 45043 non-null  object
#  15  tagline                20395 non-null  object
#  16  title                  45108 non-null  object
#  17  vote_average           42362 non-null  float64
#  18  vote_count             45108 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(11)
# memory usage: 6.9+ MB

# %%
df.isna().sum()/len(df)
# Out:
# belongs_to_collection    0.900528
# budget_musd              0.803183
# genres                   0.047442
# id                       0.000000
# original_language        0.000244
# overview                 0.021615
# popularity               0.000599
# poster_path              0.005099
# production_companies     0.255986
# production_countries     0.132172
# release_date             0.000798
# revenue_musd             0.835994
# runtime                  0.034717
# spoken_languages         0.080895
# status                   0.001441
# tagline                  0.547863
# title                    0.000000
# vote_average             0.060876
# vote_count               0.000000
# dtype: float64

# %%
df.status.value_counts()
# Out:
# status
# Released    44682
# Name: count, dtype: int64

# %%
df
# Out:
#                 belongs_to_collection  budget_musd                    genres  \
# 0                Toy Story Collection         30.0   Animation|Comedy|Family
# 1                                 NaN         65.0  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection          NaN            Romance|Comedy
# 3                                 NaN         16.0      Comedy|Drama|Romance
# 4      Father of the Bride Collection          NaN                    Comedy
# ...                               ...          ...                       ...
# 45461                             NaN          NaN              Drama|Family
# 45462                             NaN          NaN                     Drama
# 45463                             NaN          NaN     Action|Drama|Thriller
# 45464                             NaN          NaN                       NaN
# 45465                             NaN          NaN                       NaN
#
#            id original_language  \
# 0         862                en
# 1        8844                en
# 2       15602                en
# 3       31357                en
# 4       11862                en
# ...       ...               ...
# 45461  439050                fa
# 45462  111109                tl
# 45463   67758                en
# 45464  227506                en
# 45465  461257                en
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 45461        Rising and falling between a man and woman.    0.072051
# 45462  An artist struggles to finish his work while a...    0.178241
# 45463  When one of her hits goes wrong, a professiona...    0.903007
# 45464  In a small town live two brothers, one a minis...    0.003503
# 45465  50 years after decriminalisation of homosexual...    0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 45461                                                NaN
# 45462                                        Sine Olivia
# 45463                            American World Pictures
# 45464                                          Yermoliev
# 45465                                                NaN
#
#            production_countries release_date  revenue_musd  runtime  \
# 0      United States of America   1995-10-30    373.554033     81.0
# 1      United States of America   1995-12-15    262.797249    104.0
# 2      United States of America   1995-12-22           NaN    101.0
# 3      United States of America   1995-12-22     81.452156    127.0
# 4      United States of America   1995-02-10     76.578911    106.0
# ...                         ...          ...           ...      ...
# 45461                      Iran          NaT           NaN     90.0
# 45462               Philippines   2011-11-17           NaN    360.0
# 45463  United States of America   2003-08-01           NaN     90.0
# 45464                    Russia   1917-10-21           NaN     87.0
# 45465            United Kingdom   2017-06-09           NaN     75.0
#
#        spoken_languages                                            tagline  \
# 0               English                                                NaN
# 1      English|Français          Roll the dice and unleash the excitement!
# 2               English  Still Yelling. Still Fighting. Still Ready for...
# 3               English  Friends are the people who let you be yourself...
# 4               English  Just When His World Is Back To Normal... He's ...
# ...                 ...                                                ...
# 45461             فارسی         Rising and falling between a man and woman
# 45462               NaN                                                NaN
# 45463           English                             A deadly game of wits.
# 45464               NaN                                                NaN
# 45465           English                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           NaN         0.0
# 45465                     Queerama           NaN         0.0
#
# [44682 rows x 18 columns]

# %%
df.drop(columns=['status'],inplace=True)
# Out:
# /tmp/ipykernel_4147/2422845049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['status'],inplace=True)

# %%
df.columns
# Out:
# Index(['belongs_to_collection', 'budget_musd', 'genres', 'id',
#        'original_language', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue_musd', 'runtime', 'spoken_languages', 'tagline', 'title',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df
# Out:
#                 belongs_to_collection  budget_musd                    genres  \
# 0                Toy Story Collection         30.0   Animation|Comedy|Family
# 1                                 NaN         65.0  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection          NaN            Romance|Comedy
# 3                                 NaN         16.0      Comedy|Drama|Romance
# 4      Father of the Bride Collection          NaN                    Comedy
# ...                               ...          ...                       ...
# 45461                             NaN          NaN              Drama|Family
# 45462                             NaN          NaN                     Drama
# 45463                             NaN          NaN     Action|Drama|Thriller
# 45464                             NaN          NaN                       NaN
# 45465                             NaN          NaN                       NaN
#
#            id original_language  \
# 0         862                en
# 1        8844                en
# 2       15602                en
# 3       31357                en
# 4       11862                en
# ...       ...               ...
# 45461  439050                fa
# 45462  111109                tl
# 45463   67758                en
# 45464  227506                en
# 45465  461257                en
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 45461        Rising and falling between a man and woman.    0.072051
# 45462  An artist struggles to finish his work while a...    0.178241
# 45463  When one of her hits goes wrong, a professiona...    0.903007
# 45464  In a small town live two brothers, one a minis...    0.003503
# 45465  50 years after decriminalisation of homosexual...    0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 45461                                                NaN
# 45462                                        Sine Olivia
# 45463                            American World Pictures
# 45464                                          Yermoliev
# 45465                                                NaN
#
#            production_countries release_date  revenue_musd  runtime  \
# 0      United States of America   1995-10-30    373.554033     81.0
# 1      United States of America   1995-12-15    262.797249    104.0
# 2      United States of America   1995-12-22           NaN    101.0
# 3      United States of America   1995-12-22     81.452156    127.0
# 4      United States of America   1995-02-10     76.578911    106.0
# ...                         ...          ...           ...      ...
# 45461                      Iran          NaT           NaN     90.0
# 45462               Philippines   2011-11-17           NaN    360.0
# 45463  United States of America   2003-08-01           NaN     90.0
# 45464                    Russia   1917-10-21           NaN     87.0
# 45465            United Kingdom   2017-06-09           NaN     75.0
#
#        spoken_languages                                            tagline  \
# 0               English                                                NaN
# 1      English|Français          Roll the dice and unleash the excitement!
# 2               English  Still Yelling. Still Fighting. Still Ready for...
# 3               English  Friends are the people who let you be yourself...
# 4               English  Just When His World Is Back To Normal... He's ...
# ...                 ...                                                ...
# 45461             فارسی         Rising and falling between a man and woman
# 45462               NaN                                                NaN
# 45463           English                             A deadly game of wits.
# 45464               NaN                                                NaN
# 45465           English                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           NaN         0.0
# 45465                     Queerama           NaN         0.0
#
# [44682 rows x 18 columns]

# %%
col=['id','title','tagline','release_date','genres','belongs_to_collection','original_language','budget_musd','revenue_musd','production_companies','production_countries','vote_count','vote_average','popularity','runtime','overview','spoken_languages','poster_path']

# %%
df=df.loc[:,col]

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 45461  439050                       Subdue
# 45462  111109          Century of Birthing
# 45463   67758                     Betrayal
# 45464  227506             Satan Triumphant
# 45465  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 45461         Rising and falling between a man and woman          NaT
# 45462                                                NaN   2011-11-17
# 45463                             A deadly game of wits.   2003-08-01
# 45464                                                NaN   1917-10-21
# 45465                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 45461              Drama|Family                             NaN
# 45462                     Drama                             NaN
# 45463     Action|Drama|Thriller                             NaN
# 45464                       NaN                             NaN
# 45465                       NaN                             NaN
#
#       original_language  budget_musd  revenue_musd  \
# 0                    en         30.0    373.554033
# 1                    en         65.0    262.797249
# 2                    en          NaN           NaN
# 3                    en         16.0     81.452156
# 4                    en          NaN     76.578911
# ...                 ...          ...           ...
# 45461                fa          NaN           NaN
# 45462                tl          NaN           NaN
# 45463                en          NaN           NaN
# 45464                en          NaN           NaN
# 45465                en          NaN           NaN
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 45461                                                NaN
# 45462                                        Sine Olivia
# 45463                            American World Pictures
# 45464                                          Yermoliev
# 45465                                                NaN
#
#            production_countries  vote_count  vote_average  popularity  \
# 0      United States of America      5415.0           7.7   21.946943
# 1      United States of America      2413.0           6.9   17.015539
# 2      United States of America        92.0           6.5   11.712900
# 3      United States of America        34.0           6.1    3.859495
# 4      United States of America       173.0           5.7    8.387519
# ...                         ...         ...           ...         ...
# 45461                      Iran         1.0           4.0    0.072051
# 45462               Philippines         3.0           9.0    0.178241
# 45463  United States of America         6.0           3.8    0.903007
# 45464                    Russia         0.0           NaN    0.003503
# 45465            United Kingdom         0.0           NaN    0.163015
#
#        runtime                                           overview  \
# 0         81.0  Led by Woody, Andy's toys live happily in his ...
# 1        104.0  When siblings Judy and Peter discover an encha...
# 2        101.0  A family wedding reignites the ancient feud be...
# 3        127.0  Cheated on, mistreated and stepped on, the wom...
# 4        106.0  Just when George Banks has recovered from his ...
# ...        ...                                                ...
# 45461     90.0        Rising and falling between a man and woman.
# 45462    360.0  An artist struggles to finish his work while a...
# 45463     90.0  When one of her hits goes wrong, a professiona...
# 45464     87.0  In a small town live two brothers, one a minis...
# 45465     75.0  50 years after decriminalisation of homosexual...
#
#        spoken_languages                       poster_path
# 0               English  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      English|Français  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2               English  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3               English  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4               English  /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                 ...                               ...
# 45461             فارسی  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462               NaN  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463           English  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464               NaN  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465           English  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
# [44682 rows x 18 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44677  439050                       Subdue
# 44678  111109          Century of Birthing
# 44679   67758                     Betrayal
# 44680  227506             Satan Triumphant
# 44681  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 44677         Rising and falling between a man and woman          NaT
# 44678                                                NaN   2011-11-17
# 44679                             A deadly game of wits.   2003-08-01
# 44680                                                NaN   1917-10-21
# 44681                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 44677              Drama|Family                             NaN
# 44678                     Drama                             NaN
# 44679     Action|Drama|Thriller                             NaN
# 44680                       NaN                             NaN
# 44681                       NaN                             NaN
#
#       original_language  budget_musd  revenue_musd  \
# 0                    en         30.0    373.554033
# 1                    en         65.0    262.797249
# 2                    en          NaN           NaN
# 3                    en         16.0     81.452156
# 4                    en          NaN     76.578911
# ...                 ...          ...           ...
# 44677                fa          NaN           NaN
# 44678                tl          NaN           NaN
# 44679                en          NaN           NaN
# 44680                en          NaN           NaN
# 44681                en          NaN           NaN
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 44677                                                NaN
# 44678                                        Sine Olivia
# 44679                            American World Pictures
# 44680                                          Yermoliev
# 44681                                                NaN
#
#            production_countries  vote_count  vote_average  popularity  \
# 0      United States of America      5415.0           7.7   21.946943
# 1      United States of America      2413.0           6.9   17.015539
# 2      United States of America        92.0           6.5   11.712900
# 3      United States of America        34.0           6.1    3.859495
# 4      United States of America       173.0           5.7    8.387519
# ...                         ...         ...           ...         ...
# 44677                      Iran         1.0           4.0    0.072051
# 44678               Philippines         3.0           9.0    0.178241
# 44679  United States of America         6.0           3.8    0.903007
# 44680                    Russia         0.0           NaN    0.003503
# 44681            United Kingdom         0.0           NaN    0.163015
#
#        runtime                                           overview  \
# 0         81.0  Led by Woody, Andy's toys live happily in his ...
# 1        104.0  When siblings Judy and Peter discover an encha...
# 2        101.0  A family wedding reignites the ancient feud be...
# 3        127.0  Cheated on, mistreated and stepped on, the wom...
# 4        106.0  Just when George Banks has recovered from his ...
# ...        ...                                                ...
# 44677     90.0        Rising and falling between a man and woman.
# 44678    360.0  An artist struggles to finish his work while a...
# 44679     90.0  When one of her hits goes wrong, a professiona...
# 44680     87.0  In a small town live two brothers, one a minis...
# 44681     75.0  50 years after decriminalisation of homosexual...
#
#        spoken_languages                       poster_path
# 0               English  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      English|Français  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2               English  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3               English  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4               English  /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                 ...                               ...
# 44677             فارسی  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 44678               NaN  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 44679           English  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 44680               NaN  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 44681           English  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
# [44682 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44682 entries, 0 to 44681
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44682 non-null  int64
#  1   title                  44682 non-null  object
#  2   tagline                20283 non-null  object
#  3   release_date           44652 non-null  datetime64[ns]
#  4   genres                 42585 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44672 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44682 non-null  float64
#  12  vote_average           41989 non-null  float64
#  13  popularity             44656 non-null  float64
#  14  runtime                43170 non-null  float64
#  15  overview               43731 non-null  object
#  16  spoken_languages       41092 non-null  object
#  17  poster_path            44459 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(1), object(10)
# memory usage: 6.1+ MB

# %%
df.poster_path[0]
# Out:
# '/rhIRbceoE9lR4veEXuwCC2wARtG.jpg'

# %%
base_poster_url='http://image.tmdb.org/t/p/w185/'

# %%
df.poster_path="<img src='"+ base_poster_url + df.poster_path + "' style='height:100px;'>"

# %%
df.poster_path[0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//rhIRbceoE9lR4veEXuwCC2wARtG.jpg' style='height:100px;'>"

# %%
pd.read_csv('../jupyter/environment/movies_clean.csv').poster_path[0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//rhIRbceoE9lR4veEXuwCC2wARtG.jpg' style='height:100px;'>"
